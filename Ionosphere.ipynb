# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
drive.mount('/content/drive')
import pandas as pd
data = pd.read_csv('/content/drive/My Drive/Datasets/ionosphere_data.csv')
data = pd.DataFrame(data)
data
# Out:
# Mounted at /content/drive
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [351 rows x 35 columns]

# %%
drive.flush_and_unmount()
y = data['label']
df = data
del df['label']
x = df
for column in x:
  x[column].fillna(value = x[column].mean(),inplace = True)
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=0)

# %%
y_train.shape
# Out:
# (210,)

# %%
model = Sequential()
model.add(keras.layers.Flatten(input_shape=(X_train.shape[1],)))
model.add(Dense(16,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1,activation='tanh'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, verbose = 2)
# Out:
# Epoch 1/100
# 7/7 - 1s - loss: 2.1561 - accuracy: 0.3286
# Epoch 2/100
# 7/7 - 0s - loss: 1.6898 - accuracy: 0.3190
# Epoch 3/100
# 7/7 - 0s - loss: 1.4249 - accuracy: 0.3333
# Epoch 4/100
# 7/7 - 0s - loss: 1.3259 - accuracy: 0.5190
# Epoch 5/100
# 7/7 - 0s - loss: 1.2576 - accuracy: 0.6333
# Epoch 6/100
# 7/7 - 0s - loss: 1.2023 - accuracy: 0.7190
# Epoch 7/100
# 7/7 - 0s - loss: 1.1688 - accuracy: 0.7524
# Epoch 8/100
# 7/7 - 0s - loss: 1.1412 - accuracy: 0.7667
# Epoch 9/100
# 7/7 - 0s - loss: 1.1210 - accuracy: 0.7857
# Epoch 10/100
# 7/7 - 0s - loss: 1.0488 - accuracy: 0.7952
# Epoch 11/100
# 7/7 - 0s - loss: 0.9224 - accuracy: 0.8000
# Epoch 12/100
# 7/7 - 0s - loss: 0.8899 - accuracy: 0.8048
# Epoch 13/100
# 7/7 - 0s - loss: 0.8749 - accuracy: 0.8000
# Epoch 14/100
# 7/7 - 0s - loss: 0.8060 - accuracy: 0.8000
# Epoch 15/100
# 7/7 - 0s - loss: 0.7906 - accuracy: 0.8095
# Epoch 16/100
# 7/7 - 0s - loss: 0.7195 - accuracy: 0.8143
# Epoch 17/100
# 7/7 - 0s - loss: 0.5796 - accuracy: 0.8143
# Epoch 18/100
# 7/7 - 0s - loss: 0.4958 - accuracy: 0.8143
# Epoch 19/100
# 7/7 - 0s - loss: 0.4753 - accuracy: 0.8238
# Epoch 20/100
# 7/7 - 0s - loss: 0.4098 - accuracy: 0.8190
# Epoch 21/100
# 7/7 - 0s - loss: 0.3781 - accuracy: 0.8429
# Epoch 22/100
# 7/7 - 0s - loss: 0.3677 - accuracy: 0.8524
# Epoch 23/100
# 7/7 - 0s - loss: 0.3584 - accuracy: 0.8619
# Epoch 24/100
# 7/7 - 0s - loss: 0.3518 - accuracy: 0.8619
# Epoch 25/100
# 7/7 - 0s - loss: 0.3442 - accuracy: 0.8571
# Epoch 26/100
# 7/7 - 0s - loss: 0.3381 - accuracy: 0.8667
# Epoch 27/100
# 7/7 - 0s - loss: 0.3312 - accuracy: 0.8762
# Epoch 28/100
# 7/7 - 0s - loss: 0.3246 - accuracy: 0.8762
# Epoch 29/100
# 7/7 - 0s - loss: 0.3176 - accuracy: 0.8810
# Epoch 30/100
# 7/7 - 0s - loss: 0.3111 - accuracy: 0.8857
# Epoch 31/100
# 7/7 - 0s - loss: 0.3045 - accuracy: 0.8857
# Epoch 32/100
# 7/7 - 0s - loss: 0.2983 - accuracy: 0.8905
# Epoch 33/100
# 7/7 - 0s - loss: 0.2907 - accuracy: 0.8952
# Epoch 34/100
# 7/7 - 0s - loss: 0.2839 - accuracy: 0.9000
# Epoch 35/100
# 7/7 - 0s - loss: 0.2772 - accuracy: 0.9000
# Epoch 36/100
# 7/7 - 0s - loss: 0.2705 - accuracy: 0.9000
# Epoch 37/100
# 7/7 - 0s - loss: 0.2640 - accuracy: 0.9000
# Epoch 38/100
# 7/7 - 0s - loss: 0.2576 - accuracy: 0.9000
# Epoch 39/100
# 7/7 - 0s - loss: 0.2513 - accuracy: 0.9048
# Epoch 40/100
# 7/7 - 0s - loss: 0.2445 - accuracy: 0.9143
# Epoch 41/100
# 7/7 - 0s - loss: 0.2371 - accuracy: 0.9238
# Epoch 42/100
# 7/7 - 0s - loss: 0.2310 - accuracy: 0.9190
# Epoch 43/100
# 7/7 - 0s - loss: 0.2239 - accuracy: 0.9238
# Epoch 44/100
# 7/7 - 0s - loss: 0.2172 - accuracy: 0.9286
# Epoch 45/100
# 7/7 - 0s - loss: 0.2110 - accuracy: 0.9286
# Epoch 46/100
# 7/7 - 0s - loss: 0.2056 - accuracy: 0.9286
# Epoch 47/100
# 7/7 - 0s - loss: 0.1999 - accuracy: 0.9381
# Epoch 48/100
# 7/7 - 0s - loss: 0.1944 - accuracy: 0.9429
# Epoch 49/100
# 7/7 - 0s - loss: 0.1897 - accuracy: 0.9429
# Epoch 50/100
# 7/7 - 0s - loss: 0.1845 - accuracy: 0.9429
# Epoch 51/100
# 7/7 - 0s - loss: 0.1794 - accuracy: 0.9429
# Epoch 52/100
# 7/7 - 0s - loss: 0.1753 - accuracy: 0.9429
# Epoch 53/100
# 7/7 - 0s - loss: 0.1711 - accuracy: 0.9429
# Epoch 54/100
# 7/7 - 0s - loss: 0.1671 - accuracy: 0.9429
# Epoch 55/100
# 7/7 - 0s - loss: 0.1631 - accuracy: 0.9476
# Epoch 56/100
# 7/7 - 0s - loss: 0.1591 - accuracy: 0.9476
# Epoch 57/100
# 7/7 - 0s - loss: 0.1552 - accuracy: 0.9476
# Epoch 58/100
# 7/7 - 0s - loss: 0.1526 - accuracy: 0.9476
# Epoch 59/100
# 7/7 - 0s - loss: 0.1479 - accuracy: 0.9476
# Epoch 60/100
# 7/7 - 0s - loss: 0.1444 - accuracy: 0.9476
# Epoch 61/100
# 7/7 - 0s - loss: 0.1410 - accuracy: 0.9476
# Epoch 62/100
# 7/7 - 0s - loss: 0.1366 - accuracy: 0.9524
# Epoch 63/100
# 7/7 - 0s - loss: 0.1320 - accuracy: 0.9524
# Epoch 64/100
# 7/7 - 0s - loss: 0.1278 - accuracy: 0.9524
# Epoch 65/100
# 7/7 - 0s - loss: 0.1239 - accuracy: 0.9571
# Epoch 66/100
# 7/7 - 0s - loss: 0.1203 - accuracy: 0.9571
# Epoch 67/100
# 7/7 - 0s - loss: 0.1166 - accuracy: 0.9571
# Epoch 68/100
# 7/7 - 0s - loss: 0.1129 - accuracy: 0.9619
# Epoch 69/100
# 7/7 - 0s - loss: 0.1099 - accuracy: 0.9619
# Epoch 70/100
# 7/7 - 0s - loss: 0.1070 - accuracy: 0.9619
# Epoch 71/100
# 7/7 - 0s - loss: 0.1040 - accuracy: 0.9619
# Epoch 72/100
# 7/7 - 0s - loss: 0.1008 - accuracy: 0.9619
# Epoch 73/100
# 7/7 - 0s - loss: 0.0968 - accuracy: 0.9619
# Epoch 74/100
# 7/7 - 0s - loss: 0.0944 - accuracy: 0.9619
# Epoch 75/100
# 7/7 - 0s - loss: 0.0914 - accuracy: 0.9667
# Epoch 76/100
# 7/7 - 0s - loss: 0.0887 - accuracy: 0.9667
# Epoch 77/100
# 7/7 - 0s - loss: 0.0858 - accuracy: 0.9714
# Epoch 78/100
# 7/7 - 0s - loss: 0.0838 - accuracy: 0.9762
# Epoch 79/100
# 7/7 - 0s - loss: 0.0808 - accuracy: 0.9762
# Epoch 80/100
# 7/7 - 0s - loss: 0.0788 - accuracy: 0.9762
# Epoch 81/100
# 7/7 - 0s - loss: 0.0749 - accuracy: 0.9762
# Epoch 82/100
# 7/7 - 0s - loss: 0.0726 - accuracy: 0.9810
# Epoch 83/100
# 7/7 - 0s - loss: 0.0700 - accuracy: 0.9810
# Epoch 84/100
# 7/7 - 0s - loss: 0.0681 - accuracy: 0.9810
# Epoch 85/100
# 7/7 - 0s - loss: 0.0657 - accuracy: 0.9810
# Epoch 86/100
# 7/7 - 0s - loss: 0.0636 - accuracy: 0.9810
# Epoch 87/100
# 7/7 - 0s - loss: 0.0620 - accuracy: 0.9810
# Epoch 88/100
# 7/7 - 0s - loss: 0.0595 - accuracy: 0.9857
# Epoch 89/100
# 7/7 - 0s - loss: 0.0583 - accuracy: 0.9810
# Epoch 90/100
# 7/7 - 0s - loss: 0.0555 - accuracy: 0.9857
# Epoch 91/100
# 7/7 - 0s - loss: 0.0541 - accuracy: 0.9857
# Epoch 92/100
# 7/7 - 0s - loss: 0.0530 - accuracy: 0.9857
# Epoch 93/100
# 7/7 - 0s - loss: 0.0517 - accuracy: 0.9857
# Epoch 94/100
# 7/7 - 0s - loss: 0.0504 - accuracy: 0.9857
# Epoch 95/100
# 7/7 - 0s - loss: 0.0491 - accuracy: 0.9857
# Epoch 96/100
# 7/7 - 0s - loss: 0.0480 - accuracy: 0.9857
# Epoch 97/100
# 7/7 - 0s - loss: 0.0469 - accuracy: 0.9857
# Epoch 98/100
# 7/7 - 0s - loss: 0.0457 - accuracy: 0.9857
# Epoch 99/100
# 7/7 - 0s - loss: 0.0451 - accuracy: 0.9857
# Epoch 100/100
# 7/7 - 0s - loss: 0.0442 - accuracy: 0.9857

# %%
model.predict(X_test).max()
# Out:
# 0.99974954
